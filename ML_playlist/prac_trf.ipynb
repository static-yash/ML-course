# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('automobile_dataset.csv',usecols=['Make','Model','Year','Fuel_Type','Mileage','Accident_History'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              5500 non-null   str
#  1   Model             5500 non-null   str
#  2   Year              5500 non-null   int64
#  3   Fuel_Type         5500 non-null   str
#  4   Mileage           5500 non-null   int64
#  5   Accident_History  4688 non-null   float64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 356.5 KB

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Fuel_Type             0
# Mileage               0
# Accident_History    812
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

trf = ColumnTransformer([('Impute',SimpleImputer(strategy='most_frequent'),[5])])
