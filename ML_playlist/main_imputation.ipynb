# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('titanic_toy.csv')
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
df.shape
# Out:
# (891, 4)

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape, X_test.shape
# Out:
# ((712, 3), (179, 3))

# %%
X_train.isnull().mean()
# Out:
# Age       0.207865
# Fare      0.050562
# Family    0.000000
# dtype: float64

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

mean_fare = X_train['Fare'].mean()
median_fare = X_train['Fare'].median()

# %%
X_train['Age_median'] = X_train['Age'].fillna(median_age)
X_train['Age_mean'] = X_train['Age'].fillna(mean_age)


X_train['Fare_median'] = X_train['Age'].fillna(median_fare)
X_train['Fare_mean'] = X_train['Age'].fillna(mean_fare)

# %%
X_train.sample(5)
# Out:
#       Age      Fare  Family  Age_median  Age_mean  Fare_median  Fare_mean
# 338  45.0    8.0500       0        45.0      45.0         45.0       45.0
# 9    14.0   30.0708       1        14.0      14.0         14.0       14.0
# 90   29.0    8.0500       0        29.0      29.0         29.0       29.0
# 246  25.0    7.7750       0        25.0      25.0         25.0       25.0
# 380  42.0  227.5250       0        42.0      42.0         42.0       42.0

# %%
print('Original Age Variable Varience:  ',X_train['Age'].var())
print('Age Varience after imputation median',X_train['Age_median'].var())
print('Age Varience after imputation mean',X_train['Age_mean'].var())

print('Original Fare Variable Varience:  ',X_train['Fare'].var())
print('Fare Varience after imputation median',X_train['Fare_median'].var())
print('Fare Varience after imputation mean',X_train['Fare_mean'].var())
# Out:
# Original Age Variable Varience:   204.34951339046142
# Age Varience after imputation median 161.98956633460548
# Age Varience after imputation mean 161.81262452718676
# Original Fare Variable Varience:   2448.1979137063163
# Fare Varience after imputation median 200.55085535155044
# Fare Varience after imputation mean 163.13478280526172

# %%
X_train.cov()
# Out:
#                     Age         Fare     Family  Age_median    Age_mean  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917   57.957599   55.603719
# Family        -6.498901    17.258917   2.735252   -5.112563   -5.146106
# Age_median   204.349513    57.957599  -5.112563  161.989566  161.812625
# Age_mean     204.349513    55.603719  -5.146106  161.812625  161.812625
# Fare_median  204.349513    90.432552  -4.649792  164.430718  161.812625
# Fare_mean    204.349513    49.169279  -5.237797  161.328946  161.812625
#
#              Fare_median   Fare_mean
# Age           204.349513  204.349513
# Fare           90.432552   49.169279
# Family         -4.649792   -5.237797
# Age_median    164.430718  161.328946
# Age_mean      161.812625  161.812625
# Fare_median   200.550855  154.655944
# Fare_mean     154.655944  163.134783

# %%
X_train.corr()
# Out:
#                   Age      Fare    Family  Age_median  Age_mean  Fare_median  \
# Age          1.000000  0.092644 -0.299113    1.000000  1.000000     1.000000
# Fare         0.092644  1.000000  0.208268    0.091757  0.088069     0.128809
# Family      -0.299113  0.208268  1.000000   -0.242883 -0.244610    -0.198528
# Age_median   1.000000  0.091757 -0.242883    1.000000  0.999454     0.912278
# Age_mean     1.000000  0.088069 -0.244610    0.999454  1.000000     0.898243
# Fare_median  1.000000  0.128809 -0.198528    0.912278  0.898243     1.000000
# Fare_mean    1.000000  0.077538 -0.247957    0.992420  0.995939     0.855029
#
#              Fare_mean
# Age           1.000000
# Fare          0.077538
# Family       -0.247957
# Age_median    0.992420
# Age_mean      0.995939
# Fare_median   0.855029
# Fare_mean     1.000000

# %%
X_train[['Age','Age_median','Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

ax = X_train[['Age', 'Age_median', 'Age_mean']].boxplot(grid=False)
ax.set_title("Age Distribution: Original vs. Imputed")
ax.set_ylabel("Age")
plt.show()

# %%
X_train[['Fare','Fare_median','Fare_mean']].boxplot();

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
imputer1 = SimpleImputer(strategy='mean')
imputer2 = SimpleImputer(strategy='median')

# %%
trf = ColumnTransformer([
    ('imputer1',imputer1,['Fare']),
    ('imputer2',imputer2,['Age']),
],remainder='passthrough')

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(), ['Fare']),
#                                 ('imputer2', SimpleImputer(strategy='median'),
#                                  ['Age'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([32.61759689])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([28.75])

# %%
X_train = trf.transform(X_train)
X_test = trf.transform(X_test)

# %%
X_train
# Out:
# array([[ 27.7208,  40.    ,   0.    ],
#        [ 16.7   ,   4.    ,   2.    ],
#        [  9.    ,  47.    ,   0.    ],
#        ...,
#        [ 49.5042,  71.    ,   0.    ],
#        [221.7792,  28.75  ,   0.    ],
#        [ 25.925 ,  28.75  ,   0.    ]], shape=(712, 3))
